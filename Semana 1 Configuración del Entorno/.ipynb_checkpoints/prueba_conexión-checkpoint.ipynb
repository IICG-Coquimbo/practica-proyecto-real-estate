# %%
import requests
import pandas as pd

try:
    url = "https://api.exchangerate-api.com/v4/latest/USD"
    respuesta = requests.get(url)
    datos = respuesta.json()

    df = pd.DataFrame(datos['rates'].items(), columns=['Moneda', 'Valor'])

    print("Conexión exitosa! Aquí los primeros datos:")
    print(df.head())

except Exception as e:
    print(f"Error en la conexión: {e}")
# Out:
# Conexión exitosa! Aquí los primeros datos:
#   Moneda   Valor
# 0    USD    1.00
# 1    AED    3.67
# 2    AFN   63.18
# 3    ALL   83.38
# 4    AMD  377.60
