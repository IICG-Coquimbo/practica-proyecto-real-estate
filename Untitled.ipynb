# %%
import requests
import pandas as pd

# Intentemos capturar datos reales de la API de intercambio de monedas
try:
    url = "https://api.exchangerate-api.com/v4/latest/USD"
    respuesta = requests.get(url)
    datos = respuesta.json()

    # Creamos un pequeño resumen de los tipos de cambio
    df = pd.DataFrame(datos['rates'].items(), columns=['Moneda', 'Valor'])

    print("Conexión exitosa! Aquí los primeros datos capturados:")
    print(df.head())

except Exception as e:
    print(f"Error en la conexión: {e}")
# Out:
# Conexión exitosa! Aquí los primeros datos capturados:
#   Moneda   Valor
# 0    USD    1.00
# 1    AED    3.67
# 2    AFN   62.52
# 3    ALL   82.47
# 4    AMD  377.70

# %%
import requests
from bs4 import BeautifulSoup

# Configuracin de entrada
5 url = "https://cl.agentiz.com/"
6 headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen
7
8 # 1. Petici n al servidor
9 respuesta = requests.get(url, headers=headers)
10
11 # 2. Convertir el HTML en un objeto de Python
12 sopa = BeautifulSoup(respuesta.text, 'html.parser')
13
14 # 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
17
15 # Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
16 resultados = sopa.find_all('div', class_='b-property-card')
18 # 4. Mostrar en pantalla
19 for dato in resultados:
20
21
print(f"Encontrado: {dato.text.strip()}")
# Out:
#   Cell In[4], line 2
#     2 from bs4 import BeautifulSoup
#       ^
# SyntaxError: invalid syntax
