# %%
import time
from pymongo import MongoClient
from selenium import webdriver
from selenium.webdriver.common.by import By

NOMBRE_GRUPO= "G2_RealEstate"
CATEGORIA_ACTUAL= "Travel"
try:
    client = MongoClient('database', 27017)
    db = client['proyecto_bigdata']
    coleccion = db['datos_libros']
    print("CONEXION EXIASTOSA: Listo para insertar datos de", CATEGORIA_ACTUAL)
except Exception as e:
    print("ERROR DE CONEXION:", e)

lista_libros= [
    {"titulo": "It´s Only Himalaya", "precio": "45 .17"},
    {"titulo": "Full Moon over Noahs Ark", "precio": "49 .43"}
]
for libro in lista_libros:
    try: 
        registro={
        "item": libro["titulo"],
        "valor": float(libro["precio"].replace('  ','').replace(',' , '').strip()),
        "categoria": CATEGORIA_ACTUAL,
        "grupo": NOMBRE_GRUPO,
        "fecha_captura": time.strftime("%Y-%m-%d %H:%M:%S")
        }
        
        coleccion.insert_one(registro)
    except Exception as e:
        print("Error procesando libro", e)
print("PROCESO FINALIZADO: Datos enviados a MongoDB.")
# Out:
# CONEXION EXIASTOSA: Listo para insertar datos de Travel
# Error procesando libro could not convert string to float: '45 .17'
# Error procesando libro could not convert string to float: '49 .43'
# PROCESO FINALIZADO: Datos enviados a MongoDB.
