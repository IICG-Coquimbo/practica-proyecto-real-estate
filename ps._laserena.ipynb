# %%
from scrapers.scraper_laserena import ejecutar_extraccion

datos = ejecutar_extraccion()

print(type(datos))
print("Cantidad:", len(datos))
# Out:
# 🧹 Entorno virtual listo. Asignación: Páginas 2 a la 2.
#
# --- [FASE 1] Recolectando enlaces de la Página 2 ---
# Catálogo listo: 48 propiedades encontradas.
# [1/48] Inspeccionando: Arriendo Año Corrido Gc Inclui...
# [2/48] Inspeccionando: Departamento En Arriendo En Un...
# [3/48] Inspeccionando: Dpto Amoblado Año Corrido / Pr...
# [4/48] Inspeccionando: Departamento Nuevo, Arriendo H...
# [5/48] Inspeccionando: Marzo A Diciembre, A Pasos De ...
# [6/48] Inspeccionando: Sin Amoblar, Peñuelas - Legacy...
# [7/48] Inspeccionando: Aqua, Av. Del Mar - Legacy Pro...
# [8/48] Inspeccionando: Departamento Arriendo 3 Habita...
# [9/48] Inspeccionando: Depto Amoblado Piso 8 - Condom...
# [10/48] Inspeccionando: Departamento Acogedor Y Centra...
# [11/48] Inspeccionando: Departamento Año Corrido A Pas...
# [12/48] Inspeccionando: Arriendo Departamento Hac. Tej...
# [13/48] Inspeccionando: Departamento En Arriendo Lagun...
# [14/48] Inspeccionando: Amplio Y Luminoso Departameno ...
# ...
