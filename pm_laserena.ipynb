# %%
# !python main_laserena.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from scraper_laserena import ejecutar_extraccion
#       3 datos = ejecutar_extraccion()
#       5 print(type(datos))
#
# ModuleNotFoundError: No module named 'scraper_laserena'
