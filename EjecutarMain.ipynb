# %%
# !python main.py
# Out:
# 🧹 Limpieza de procesos y temporales completada.
# 🚀 Navegador iniciado correctamente.
# 🔍 Iniciando extracción masiva de rubro Mascotas...
# ✅ Tiendanimal P1: 32 detectados, 32 válidos.
# ✅ Tiendanimal P2: 32 detectados, 64 válidos.
# ✅ Tiendanimal P3: 32 detectados, 96 válidos.
# ✅ Tiendanimal P4: 32 detectados, 128 válidos.
# ✅ Tiendanimal P5: 32 detectados, 160 válidos.
# ✅ Tiendanimal P6: 32 detectados, 192 válidos.
# ✅ Tiendanimal P7: 32 detectados, 224 válidos.
# ✅ Tiendanimal P8: 32 detectados, 256 válidos.
# ✅ Tiendanimal P9: 32 detectados, 288 válidos.
# ✅ Tiendanimal P10: 32 detectados, 320 válidos.
# ✅ Tiendanimal P11: 32 detectados, 352 válidos.
# ✅ Tiendanimal P12: 32 detectados, 384 válidos.
# ✅ Tiendanimal P13: 32 detectados, 416 válidos.
# ✅ Tiendanimal P14: 32 detectados, 448 válidos.
# ✅ Tiendanimal P15: 32 detectados, 480 válidos.
# ✅ Tiendanimal completado.
# 📊 Total capturado: 480 registros.
# 📤 Subiendo datos a MongoDB Atlas...
# ...
