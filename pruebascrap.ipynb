# %%
from scrapers.scraper_melany import ejecutar_extraccion

datos = ejecutar_extraccion()

print(type(datos))
print("Cantidad:", len(datos))
print(datos[:2])
# Out:
# <class 'list'>
# Cantidad: 48
# [{'identificador': 'Se Arrienda Departamento Marzo A Diciembre Costa Elqui', 'valor': 650000.0, 'grupo': 'RealEstate', 'integrante': 'melany-torres'}, {'identificador': 'Edificio Manuel Jesús Rivera (1 Est. 1 Bod.) Vista Sur Pis', 'valor': 390000.0, 'grupo': 'RealEstate', 'integrante': 'melany-torres'}]
