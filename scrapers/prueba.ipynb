# %%
import sys
import os

# 1. Forzamos a Python a agregar la ruta actual a su radar de búsqueda
sys.path.append(os.path.abspath(os.getcwd()))

# 2. Ahora sí, hacemos el import
from scraper_laserena import ejecutar_extraccion
import pandas as pd

# 3. Probamos
mis_datos = ejecutar_extraccion()
print(f"¡Éxito! Datos extraídos: {len(mis_datos)}")
# Out:
# Entorno listo. Procesando Pág 12 | Segmento: Primeras 20 tarjetas.
#
# --- [FASE 1] Navegando a Página 12 ---
# Página cargada (48 total). Extrayendo 20 tarjetas asignadas.
#
# --- [FASE 2] Iniciando buceo profundo en 20 publicaciones ---
# [1/20] Analizando: Se Arrienda Frente Al Mar 3d-2b Sin...
#    -> No se pudo leer la tabla. Valor a 0.0
# [2/20] Analizando: Excelente Depto En Arriendo Año Cor...
# [3/20] Analizando: Cómodo Y Moderno Departamento 2d 2b...
# [4/20] Analizando: Depto Arriendo Amoblado De 1 Dorm, ...
# [5/20] Analizando: Arriendo Departamento 1hab 1ba Coqu...
# [6/20] Analizando: Arriendo Marzo Diciembre Frente Al ...
# [7/20] Analizando: Depto 1 Dorm En Arriendo En La Sere...
# [8/20] Analizando: Se Arrienda: Dpto. Nuevo En La Sere...
# [9/20] Analizando: Arriendo Departamento 3hab 1ba La S...
#    -> No se pudo leer la tabla. Valor a 0.0
# [10/20] Analizando: Arriendo Departamento Serena  (1542...
#    -> No se pudo leer la tabla. Valor a 0.0
# [11/20] Analizando: Se Arrienda Año Corrido Full Amobla...
# [12/20] Analizando: A Pasos Del Enjoy, Disponibilidad I...
# [13/20] Analizando: Arriendo Departamento En Av Pacífic...
# [14/20] Analizando: Arriendo En Apart Hotel Sin Garantí...
# [15/20] Analizando: Arriendo Departamento Año Corrido M...
# [16/20] Analizando: La Serena Departamento Cómodo Segur...
# [17/20] Analizando: Departamento Espacioso 1 Dormitorio...
# [18/20] Analizando: Se Arrienda Dpto. 3d/2b, Amoblado, ...
#    -> No se pudo leer la tabla. Valor a 0.0
# [19/20] Analizando: Arriendo Año Corrido Barrio Univers...
# [20/20] Analizando: Pacifico 3100 Hermoso Departamento ...
#
# Navegador Selenium cerrado.
# ¡Éxito! Datos extraídos: 20
