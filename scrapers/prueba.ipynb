# %%
import sys
import os

# 1. Forzamos a Python a agregar la ruta actual a su radar de búsqueda
sys.path.append(os.path.abspath(os.getcwd()))

# 2. Ahora sí, hacemos el import
from scraper_millaray_zalazar1 import ejecutar_extraccion
import pandas as pd

# 3. Probamos
mis_datos = ejecutar_extraccion()
print(f"¡Éxito! Datos extraídos: {len(mis_datos)}")
# Out:
# Entorno virtual listo. Asignación: Páginas 1 a la 6.
#
# --- [FASE 1] Recolectando enlaces de la Página 1 ---
#
# --- [FASE 1] Recolectando enlaces de la Página 2 ---
#
# --- [FASE 1] Recolectando enlaces de la Página 3 ---
#
# --- [FASE 1] Recolectando enlaces de la Página 4 ---
#
# --- [FASE 1] Recolectando enlaces de la Página 5 ---
#
# --- [FASE 1] Recolectando enlaces de la Página 6 ---
#
# Catálogo listo: 266 propiedades encontradas. Recolectando amenidades...
# [1/266] Inspeccionando: Año Corrido , En Condominio Al...
# [2/266] Inspeccionando: Año Corrido, Amoblado En Condo...
# [3/266] Inspeccionando: Se Arrienda Departamento Marzo...
# [4/266] Inspeccionando: Edificio Manuel Jesús Rivera (...
# [5/266] Inspeccionando: Arriendo Hermoso Penthouse A P...
# [6/266] Inspeccionando: Arriendo Departamento Amoblado...
# [7/266] Inspeccionando: Arriendo Departamento Avda. Lo...
# [8/266] Inspeccionando: Acogedor Depto Amoblado En La ...
# ...

# %%
import sys
import os
import pandas as pd

# 1. Forzamos a Python a agregar la ruta actual a su radar de búsqueda
sys.path.append(os.path.abspath(os.getcwd()))

# 2. Ahora sí, hacemos el import (Asegúrate de poner el nombre correcto de tu archivo .py)
from scraper_millaray_zalazar1 import ejecutar_extraccion

# 3. Ejecutamos el bot
print("Iniciando prueba de extracción...")
mis_datos = ejecutar_extraccion()

# 4. Verificamos y visualizamos
if mis_datos:
    print(f"\n¡Éxito total! Se extrajeron {len(mis_datos)} propiedades.")
    
    # Transformamos la lista en un DataFrame (Tabla)
    df = pd.DataFrame(mis_datos)
    
    print("\n--- MUESTRA DE LOS PRIMEROS 5 REGISTROS ---")
    # Seleccionamos solo algunas columnas para que no se desordene en la terminal
    # Aquí es donde verás la magia de tu nueva etiqueta "imagen"
    columnas_a_ver = ['titulo', 'precio', 'ubicacion', 'imagen']
    
    # Imprimimos las primeras 5 filas
    print(df[columnas_a_ver].head())
    
else:
    print("\n⚠️ Ups, la lista está vacía. El bot no trajo nada.")
# Out:
# Iniciando prueba de extracción...
# Entorno virtual listo. Asignación: Páginas 1 a la 1.
# Error crítico en Selenium: Could not reach host. Are you offline?
#
# ⚠️ Ups, la lista está vacía. El bot no trajo nada.
