# %%
from melany_torres import ejecutar_extraccion

datos = ejecutar_extraccion()
 
datos
# Out:
# Entorno virtual listo. Asignación: Páginas 1 a la 1.
#
# --- [FASE 1] Recolectando enlaces de la Página 1 ---
# Tarjetas detectadas: 48
#
# Catálogo listo: 48 propiedades encontradas.
# Recolectando información interna de cada propiedad...
# [1/48] Inspeccionando: Arriendo Departamento Amoblado A Pasos D...
# [2/48] Inspeccionando: Arriendo Depto Amoblado 3d Primer Piso A...
# [3/48] Inspeccionando: Arriendo Depto 3d 2b Vista Al Mar Peñuel...
# [4/48] Inspeccionando: Departamento Avenida Del Mar Id: 169064...
# [5/48] Inspeccionando: Departamento Avenida Costanera Del Rio S...
# [6/48] Inspeccionando: Arriendo San Joaquin Barrio Universitari...
# [7/48] Inspeccionando: Departamento Nuevo Orientación Nororient...
# [8/48] Inspeccionando: Arriendo Departamento La Serena: Altos D...
# [9/48] Inspeccionando: La Serena Departamento Cómodo Seguro Cer...
#
# Navegador cerrado.
# Unexpected exception formatting exception. Falling back to standard exception
# ...
