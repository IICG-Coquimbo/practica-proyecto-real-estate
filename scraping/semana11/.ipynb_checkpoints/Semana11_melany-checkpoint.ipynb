# %%
import os

os.makedirs("semana11", exist_ok=True)

print("Carpeta creada")
# Out:
# Carpeta creada

# %%
from pymongo import MongoClient
import certifi

URI_MONGO = "mongodb+srv://bd_realestate:abc123456@c-realestate.xyfip8o.mongodb.net/"

client = MongoClient(
    URI_MONGO,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=10000
)

print("Conectando...")
print(client.server_info())
# Out:
# Conectando...
# {'version': '8.0.23', 'gitVersion': 'ccf0d81588377542f00eeecf1b1ffbc095b1eeff', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 23, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1779886561, 5), 'signature': {'hash': b'\xcfr\xfa\x10V\xd2\xab{U\xcc\x0bb\x07\x0c($20^\xef', 'keyId': 7600784725875097603}}, 'operationTime': Timestamp(1779886561, 5)}

# %%
print(client.list_database_names())
# Out:
# ['BD_RealEstate', 'admin', 'local']

# %%
for db_name in client.list_database_names():
    db = client[db_name]

    print(f"\nBASE: {db_name}")

    for col in db.list_collection_names():
        cantidad = db[col].count_documents({})
        print(f" - {col}: {cantidad}")
# Out:
# BASE: BD_RealEstate
#  - Propiedades: 2966
#
# BASE: admin
#
# BASE: local
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 print(f"\nBASE: {db_name}")
#       6 for col in db.list_collection_names():
# ----> 7     cantidad = db[col].count_documents({})
#       8     print(f" - {col}: {cantidad}")
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:2162, in Collection.count_documents(self, filter, session, comment, **kwargs)
#    2159         return 0
#    2160     return result["n"]
# -> 2162 return self._retryable_non_cursor_read(_cmd, session, _Op.COUNT)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:2176, in Collection._retryable_non_cursor_read(self, func, session, operation)
#    2174 client = self._database.client
#    2175 with client._tmp_session(session) as s:
# -> 2176     return client._retryable_read(func, self._read_preference_for(s), s, operation)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2076, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id, is_run_command, is_aggregate_write)
#    2072 retryable = bool(
#    2073     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2074 )
#    2075 with self._tmp_session(session) as s:
# -> 2076     return self._retry_internal(
#    2077         func,
#    2078         s,
#    2079         None,
#    2080         operation,
#    2081         is_read=True,
#    2082         address=address,
#    2083         read_pref=read_pref,
#    2084         retryable=retryable,
#    2085         operation_id=operation_id,
#    2086         is_run_command=is_run_command,
#    2087         is_aggregate_write=is_aggregate_write,
#    2088     )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2038, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id, is_run_command, is_aggregate_write)
#    1995 @_csot.apply
#    1996 def _retry_internal(
#    1997     self,
#    (...)
#    2008     is_aggregate_write: bool = False,
#    2009 ) -> T:
#    2010     """Internal retryable helper for all client transactions.
#    2011
#    2012     :param func: Callback function we want to retry
#    (...)
#    2023     :return: Output of the calling func()
#    2024     """
#    2025     return _ClientConnectionRetryable(
#    2026         mongo_client=self,
#    2027         func=func,
#    2028         bulk=bulk,
#    2029         operation=operation,
#    2030         is_read=is_read,
#    2031         session=session,
#    2032         read_pref=read_pref,
#    2033         address=address,
#    2034         retryable=retryable,
#    2035         operation_id=operation_id,
#    2036         is_run_command=is_run_command,
#    2037         is_aggregate_write=is_aggregate_write,
# -> 2038     ).run()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2811, in _ClientConnectionRetryable.run(self)
#    2809 self._check_last_error(check_csot=True)
#    2810 try:
# -> 2811     res = self._read() if self._is_read else self._write()
#    2812     # Track whether the transaction has completed a command.
#    2813     # If we need to apply backpressure to the first command,
#    2814     # we will need to revert back to starting state.
#    2815     if self._session is not None and self._session.in_transaction:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:3043, in _ClientConnectionRetryable._read(self)
#    3035 if self._retrying:
#    3036     _debug_log(
#    3037         _COMMAND_LOGGER,
#    3038         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)
#    3041         operationId=self._operation_id,
#    3042     )
# -> 3043 return self._func(self._session, self._server, conn, read_pref)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:2157, in Collection.count_documents.<locals>._cmd(session, _server, conn, read_preference)
#    2155 cmd: dict[str, Any] = {"aggregate": self._name, "pipeline": pipeline, "cursor": {}}
#    2156 cmd.update(kwargs)
# -> 2157 result = self._aggregate_one_result(conn, read_preference, cmd, collation, session)
#    2158 if not result:
#    2159     return 0
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:2015, in Collection._aggregate_one_result(self, conn, read_preference, cmd, collation, session)
#    2006 def _aggregate_one_result(
#    2007     self,
#    2008     conn: Connection,
#    (...)
#    2012     session: Optional[ClientSession],
#    2013 ) -> Optional[Mapping[str, Any]]:
#    2014     """Internal helper to run an aggregate that returns a single result."""
# -> 2015     result = self._command(
#    2016         conn,
#    2017         cmd,
#    2018         read_preference,
#    2019         allowable_errors=[26],  # Ignore NamespaceNotFound.
#    2020         codec_options=self._write_response_codec_options,
#    2021         read_concern=self.read_concern,
#    2022         collation=collation,
#    2023         session=session,
#    2024     )
#    2025     # cursor will not be present for NamespaceNotFound errors.
#    2026     if "cursor" not in result:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:615, in Collection._command(self, conn, command, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     589 """Internal command helper.
#     590
#     591 :param conn` - A Connection instance.
#    (...)
#     612 :return: The result document.
#     613 """
#     614 with self._database.client._tmp_session(session) as s:
# --> 615     return conn.command(
#     616         self._database.name,
#     617         command,
#     618         read_preference or self._read_preference_for(session),
#     619         codec_options or self.codec_options,
#     620         check,
#     621         allowable_errors,
#     622         read_concern=read_concern,
#     623         write_concern=write_concern,
#     624         parse_write_concern_error=True,
#     625         collation=collation,
#     626         session=s,
#     627         client=self._database.client,
#     628         retryable_write=retryable_write,
#     629         user_fields=user_fields,
#     630     )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/helpers.py:53, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      50 from pymongo.synchronous.pool import Connection
#      52 try:
# ---> 53     return func(*args, **kwargs)
#      54 except OperationFailure as exc:
#      55     if no_reauth:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/pool.py:431, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     429 # Catch socket.error, KeyboardInterrupt, CancelledError, etc. and close ourselves.
#     430 except BaseException as error:
# --> 431     self._raise_connection_failure(error)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/pool.py:403, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     401     self._raise_if_not_writable(unacknowledged)
#     402 try:
# --> 403     return command(
#     404         self,
#     405         dbname,
#     406         spec,
#     407         self.is_mongos,
#     408         read_preference,
#     409         codec_options,  # type: ignore[arg-type]
#     410         session,
#     411         client,
#     412         check,
#     413         allowable_errors,
#     414         self.address,
#     415         listeners,
#     416         self.max_bson_size,
#     417         read_concern,
#     418         parse_write_concern_error=parse_write_concern_error,
#     419         collation=collation,
#     420         compression_ctx=self.compression_context,
#     421         use_op_msg=self.op_msg_enabled,
#     422         unacknowledged=unacknowledged,
#     423         user_fields=user_fields,
#     424         exhaust_allowed=exhaust_allowed,
#     425         write_concern=write_concern,
#     426     )
#     427 except (OperationFailure, NotPrimaryError):
#     428     raise
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/network.py:198, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     196     response_doc: _DocumentOut = {"ok": 1}
#     197 else:
# --> 198     reply = receive_message(conn, request_id)
#     199     conn.more_to_come = reply.more_to_come
#     200     unpacked_docs = reply.unpack_response(
#     201         codec_options=codec_options, user_fields=user_fields
#     202     )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/network_layer.py:353, in receive_data(conn, length, deadline)
#     350             short_timeout = _POLL_TIMEOUT
#     351         conn.set_conn_timeout(short_timeout)
# --> 353     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     354 except BLOCKING_IO_ERRORS:
#     355     if conn.cancel_context.cancelled:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/network_layer.py:469, in NetworkingInterface.recv_into(self, buffer)
#     468 def recv_into(self, buffer: bytes | memoryview) -> int:
# --> 469     return self.conn.recv_into(buffer)
#
# File /opt/conda/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("EDA_RealEstate_Melany") \
    .config(
        "spark.jars.packages",
        "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1"
    ) \
    .config(
        "spark.mongodb.read.connection.uri",
        URI_MONGO
    ) \
    .config(
        "spark.mongodb.write.connection.uri",
        URI_MONGO
    ) \
    .config(
        "spark.mongodb.read.database",
        "BD_RealEstate"
    ) \
    .config(
        "spark.mongodb.read.collection",
        "Propiedades"
    ) \
    .getOrCreate()

print("Spark Atlas conectado")
# Out:
# Spark Atlas conectado

# %%
df = spark.read \
    .format("mongodb") \
    .option("database", "BD_RealEstate") \
    .option("collection", "Propiedades") \
    .load()

# %%
print(df.count())
# Out:
# 2966

# %%
df.printSchema()
# Out:
# root
#  |-- _id: string (nullable = true)
#  |-- banos: integer (nullable = true)
#  |-- dormitorios: integer (nullable = true)
#  |-- enlace: string (nullable = true)
#  |-- estacionamiento: integer (nullable = true)
#  |-- fecha_extraccion: string (nullable = true)
#  |-- gimnasio: integer (nullable = true)
#  |-- imagen: string (nullable = true)
#  |-- lavanderia: integer (nullable = true)
#  |-- m2: integer (nullable = true)
#  |-- piscina: integer (nullable = true)
#  |-- precio: integer (nullable = true)
#  |-- quincho: integer (nullable = true)
#  |-- responsable: string (nullable = true)
#  |-- terraza: integer (nullable = true)
#  |-- titulo: string (nullable = true)
#  |-- ubicacion: string (nullable = true)

# %%
df.show(5, truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+-------------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+----+-------+-------+-------+----------------+-------+---------------------------------------+---------+
# |_id                                                                                                                                                      |banos|dormitorios|enlace                                                                                                                                                   |estacionamiento|fecha_extraccion   |gimnasio|imagen                                                                                                                                                                                                                                                                                                                                                                                 |lavanderia|m2  |piscina|precio |quincho|responsable     |terraza|titulo                                 |ubicacion|
# +---------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+-------------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+----+-------+-------+-------+----------------+-------+---------------------------------------+---------+
# |https://casas.mitula.cl/adform/24301-256-3585-52db5f22d6c8-b51c-b07ae867-1e6d?page=16&pos=22&t_sec=1&t_pvid=ce484b53-61c1-491e-9939-9b737527fe67&hd=false|1    |1          |https://casas.mitula.cl/adform/24301-256-3585-52db5f22d6c8-b51c-b07ae867-1e6d?page=16&pos=22&t_sec=1&t_pvid=ce484b53-61c1-491e-9939-9b737527fe67&hd=false|0              |2026-05-01 21:14:18|0       |https://img.mitula.|0         |NULL|0      |45000  |0      |Constanza Torres|0      |Sin título                             |la serena|
# |https://casas.mitula.cl/adform/24301-256-42b2-be936457fd30-b990-8a1caa57-45f8?page=7&pos=18&t_sec=1&t_pvid=e9614c1f-ff92-456a-9bbc-28e7451fcb9a&hd=false |1    |2          |https://casas.mitula.cl/adform/24301-256-42b2-be936457fd30-b990-8a1caa57-45f8?page=7&pos=18&t_sec=1&t_pvid=e9614c1f-ff92-456a-9bbc-28e7451fcb9a&hd=false |1              |2026-05-01 21:12:48|0       |https://img.mitula.|0         |44  |1      |490000 |0      |Constanza Torres|0      |Arriendo departamento nuevo en Peñuelas|coquimbo |
# |https://casas.mitula.cl/adform/24301-256-4522-40c0f65c700e-b354-425c645f-f096?page=6&pos=27&t_sec=1&t_pvid=d8b8cd06-36f6-4b7d-84d6-73b27ecd1dba&hd=false |2    |3          |https://casas.mitula.cl/adform/24301-256-4522-40c0f65c700e-b354-425c645f-f096?page=6&pos=27&t_sec=1&t_pvid=d8b8cd06-36f6-4b7d-84d6-73b27ecd1dba&hd=false |0              |2026-05-01 21:12:38|0       |https://img.mitula.|0         |74  |0      |650000 |0      |Constanza Torres|0      |Sin título                             |coquimbo |
# |https://casas.mitula.cl/adform/24301-256-4614-faf746600cf1-8c43-aff34df3-5a28?page=3&pos=2&t_sec=1&t_pvid=fca5eec1-8dac-4aef-b40b-b0bc37e1cf1c&hd=false  |1    |2          |https://casas.mitula.cl/adform/24301-256-4614-faf746600cf1-8c43-aff34df3-5a28?page=3&pos=2&t_sec=1&t_pvid=fca5eec1-8dac-4aef-b40b-b0bc37e1cf1c&hd=false  |0              |2026-05-01 21:12:09|0       |https://img.mitula.|0         |48  |0      |550000 |0      |Constanza Torres|0      |Sin título                             |la serena|
# |https://casas.mitula.cl/adform/24301-256-4753-295964092dba-a59f-1b627919-f54c?page=5&pos=3&t_sec=1&t_pvid=bf6ce94d-1cd4-4b7e-af62-9d7888853053&hd=false  |2    |3          |https://casas.mitula.cl/adform/24301-256-4753-295964092dba-a59f-1b627919-f54c?page=5&pos=3&t_sec=1&t_pvid=bf6ce94d-1cd4-4b7e-af62-9d7888853053&hd=false  |0              |2026-05-01 21:12:28|0       |https://img.mitula.|0         |85  |0      |1200000|0      |Constanza Torres|0      |Sin título                             |la serena|
# +---------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+-------------------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+----+-------+-------+-------+----------------+-------+---------------------------------------+---------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, count, when

df.select([
    count(when(col(c).isNull(), c)).alias(c)
    for c in df.columns
]).show()
# Out:
# +---+-----+-----------+------+---------------+----------------+--------+------+----------+---+-------+------+-------+-----------+-------+------+---------+
# |_id|banos|dormitorios|enlace|estacionamiento|fecha_extraccion|gimnasio|imagen|lavanderia| m2|piscina|precio|quincho|responsable|terraza|titulo|ubicacion|
# +---+-----+-----------+------+---------------+----------------+--------+------+----------+---+-------+------+-------+-----------+-------+------+---------+
# |  0|    1|          2|     0|            466|               0|     520|     0|       520|447|    520|     0|    520|          0|    520|     0|        0|
# +---+-----+-----------+------+---------------+----------------+--------+------+----------+---+-------+------+-------+-----------+-------+------+---------+

# %%
df.describe([
    "precio",
    "m2",
    "dormitorios",
    "banos"
]).show()
# Out:
# +-------+-------------------+-----------------+------------------+------------------+
# |summary|             precio|               m2|       dormitorios|             banos|
# +-------+-------------------+-----------------+------------------+------------------+
# |  count|               2966|             2519|              2964|              2965|
# |   mean| 1722274.9305461901|123.0932909884875|2.3370445344129553|1.6340640809443507|
# | stddev|1.057022534175604E7| 544.608195136591|0.9393150127924753|0.5726443644112612|
# |    min|               1051|                0|                 0|                 0|
# |    max|          450000000|            12011|                32|                 5|
# +-------+-------------------+-----------------+------------------+------------------+

# %%
from pyspark.sql import functions as F

df.groupBy("dormitorios") \
    .agg(
        F.avg("precio").alias("precio_promedio")
    ) \
    .orderBy("dormitorios") \
    .show()
# Out:
# +-----------+------------------+
# |dormitorios|   precio_promedio|
# +-----------+------------------+
# |       NULL|          552554.5|
# |          0| 683683.3333333334|
# |          1|1189056.4407407406|
# |          2|1612841.4756756758|
# |          3| 1993638.910267472|
# |          4|1983846.5384615385|
# |          5|          980000.0|
# |         22|          500000.0|
# |         32|          450000.0|
# +-----------+------------------+

# %%
df.groupBy("ubicacion") \
    .agg(
        F.avg("precio").alias("precio_promedio"),
        F.count("*").alias("cantidad")
    ) \
    .orderBy(F.desc("cantidad")) \
    .show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------+------------------+--------+
# |ubicacion                                                                            |precio_promedio   |cantidad|
# +-------------------------------------------------------------------------------------+------------------+--------+
# |la serena                                                                            |2213125.321885522 |1485    |
# |coquimbo                                                                             |1580808.7974413645|938     |
# |ovalle                                                                               |887046.0909090909 |22      |
# |avenida del mar, la serena                                                           |715500.0          |20      |
# |la serena, avenida del mar                                                           |669285.7142857143 |14      |
# |la serena, san joaquín                                                               |812727.2727272727 |11      |
# |avenida del mar, avenida del mar, la serena                                          |653333.3333333334 |9       |
# |avenida los pescadores, avenida del mar, la serena                                   |728888.8888888889 |9       |
# |avenida pacífico, avenida del mar, la serena                                         |426057.14285714284|7       |
# |san joaquín, la serena                                                               |552857.1428571428 |7       |
# |avenida las higueras, avenida del mar, la serena                                     |745000.0          |6       |
# |emilio apey, avenida del mar, la serena                                              |520000.0          |6       |
# |puertas del mar, puerta del mar, la serena                                           |532000.0          |5       |
# |avenida cruz del molino, puerta del mar, la serena                                   |686000.0          |5       |
# |puerta del mar, la serena                                                            |710000.0          |4       |
# |avenida pacifico, puerta del mar, la serena                                          |725000.0          |4       |
# |laguna del mar - avenida cruz del molino, la serena, chile, puerta del mar, la serena|872500.0          |4       |
# |avenida gabriela mistral, san joaquín, la serena                                     |546666.6666666666 |3       |
# |avenida costanera, avenida del mar, la serena                                        |766666.6666666666 |3       |
# |avenida libertad, puerta del mar, la serena                                          |563333.3333333334 |3       |
# +-------------------------------------------------------------------------------------+------------------+--------+
# only showing top 20 rows

# %%
df.groupBy("piscina") \
    .count() \
    .show()
# Out:
# +-------+-----+
# |piscina|count|
# +-------+-----+
# |   NULL|  520|
# |      1| 1418|
# |      0| 1028|
# +-------+-----+

# %%
df.select(
    "titulo",
    "ubicacion",
    "precio",
    "m2"
).orderBy(
    F.desc("precio")
).show(10, truncate=False)
# Out:
# +----------------------------------------------------------------+---------+---------+----+
# |titulo                                                          |ubicacion|precio   |m2  |
# +----------------------------------------------------------------+---------+---------+----+
# |Depto Amoblado en Puertas del Mar 3D y 2B | La Serena – $450.000|la serena|450000000|54  |
# |Mauricio.mrodriguezp@gmail.com                                  |la serena|130000000|69  |
# |Arriendo Dpto. año corrido Laguna del Mar (114861)              |la serena|110000015|NULL|
# |Casa en venta Punta Mira                                        |coquimbo |100000000|0   |
# |DEPARTAMENTO Condominio Infinite                                |la serena|95000010 |0   |
# |SE ARRIENDA DEPARTAMENTO NUEVO EN PEÑUELAS                      |la serena|65000013 |NULL|
# |Av. Costanera 5551 (1 Est ) [3877-4]                            |coquimbo |60000033 |NULL|
# |Arriendo departamento amoblado Club Oceano, Coquimbo            |coquimbo |60000014 |NULL|
# |Arriendo departamento frente al mar, La Serena                  |coquimbo |60000014 |NULL|
# |DEPARTAMENTO avenida pacifico 740                               |la serena|60000014 |702 |
# +----------------------------------------------------------------+---------+---------+----+
# only showing top 10 rows

# %%
df_limpio = df.filter(
    (col("precio") > 100000) &
    (col("precio") < 5000000) &
    (col("m2") > 10)
)

print("Registros originales:", df.count())
print("Registros limpios:", df_limpio.count())
# Out:
# Registros originales: 2966
# Registros limpios: 1950

# %%
df.groupBy("ubicacion") \
    .count() \
    .orderBy(F.desc("count")) \
    .show()
# Out:
# +--------------------+-----+
# |           ubicacion|count|
# +--------------------+-----+
# |           la serena| 1485|
# |            coquimbo|  938|
# |              ovalle|   22|
# |avenida del mar, ...|   20|
# |la serena, avenid...|   14|
# |la serena, san jo...|   11|
# |avenida del mar, ...|    9|
# |avenida los pesca...|    9|
# |avenida pacífico,...|    7|
# |san joaquín, la s...|    7|
# |avenida las higue...|    6|
# |emilio apey, aven...|    6|
# |puertas del mar, ...|    5|
# |avenida cruz del ...|    5|
# |puerta del mar, l...|    4|
# |avenida pacifico,...|    4|
# |laguna del mar - ...|    4|
# |avenida gabriela ...|    3|
# |avenida costanera...|    3|
# |avenida libertad,...|    3|
# +--------------------+-----+
# only showing top 20 rows

# %%
df.stat.corr("m2", "precio")
# Out:
# -0.001204336049230605

# %%
df_limpio.write \
    .mode("overwrite") \
    .json("/home/jovyan/work/scraping/semana11/datos_limpios")
