# %%
from pymongo import MongoClient
import certifi

uri = "mongodb+srv://bd_realestate:abc123456@c-realestate.xyfip8o.mongodb.net/?appName=C-RealEstate"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print(" Conexión exitosa")
except Exception as e:
    print(" Error:", e)
# Out:
# {'version': '8.0.20', 'gitVersion': '28927c60881a488fcbc5fd4d925b410f33258827', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 20, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1776862685, 1), 'signature': {'hash': b'\xf62@*\x17w\x01\xd1\xac5\xc9\xd8C.\xac\x9dN\xca\xf5\xb8', 'keyId': 7568938655771787266}}, 'operationTime': Timestamp(1776862685, 1)}
#  Conexión exitosa

# %%
db = client["prueba"]
coleccion = db["personas"]

coleccion.insert_one({"nombre": "Jesús", "edad": 60})
# Out:
# InsertOneResult(ObjectId('69e8c5eca62afcec009c2118'), acknowledged=True)
