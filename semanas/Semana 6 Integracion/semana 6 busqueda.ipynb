# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
                          options=options
                         )

print("Abriendo navegador en el contenedor...")
driver.get("https://www.portalinmobiliario.com/")
print("\n ACCION REQUERIDA:")
print("1. Ve a la pestaña del escritorio del contenedor (VNC).")
print("2. Verifica si aparece un Captcha y resuelvelo manualmente.")
print("3. Una vez que veas el listado de laptops, regresa aquí.")

input("\ n Presiona ENTER en esta celda cuando e s t s listo para continuar ...")
html_check = driver.page_source.lower()
if "captcha" in html_check or "robot" in html_check:
    print("ADVERTENCIA: Aún se detecta un bloqueo en el HTML.")
else:
    print("Confirmado: Navegador listo y sin bloqueos evidentes.")

propiedades = driver.find_elements(By.CSS_SELECTOR, "li.ui-search-layout__item")
print(f"Se encontraron {len(propiedades)} propiedades")

for p in propiedades[:3]:
    try:
        titulo = p.find_element(By.CSS_SELECTOR, "h2").text
        precio = p.find_element(By.CSS_SELECTOR, ".price-tag-fraction").text
        print("-----")
        print("Titulo:", titulo)
        print("Precio:", precio)
    except:
        continue
